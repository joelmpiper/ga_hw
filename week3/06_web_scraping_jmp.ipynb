# %% [markdown]
# # Web Scraping with BeautifulSoup
# http://www.crummy.com/software/BeautifulSoup/bs4/doc/#

# %% [markdown]
# What is web scraping?
# - Extracting information from websites (simulates a human copying and pasting)
# - Based on finding patterns in website code (usually HTML)
#
# What are best practices for web scraping?
# - Scraping too many pages too fast can get your IP address blocked
# - Pay attention to the robots exclusion standard (robots.txt)
# - Let's look at http://www.imdb.com/robots.txt
#
# What is HTML?
# - Code interpreted by a web browser to produce ("render") a web page
# - Let's look at example.html
# - Tags are opened and closed
# - Tags have optional attributes
#
# How to view HTML code:
# - To view the entire page: "View Source" or "View Page Source" or "Show Page Source"
# - To view a specific part: "Inspect Element"
# - Safari users: Safari menu, Preferences, Advanced, Show Develop menu in menu bar
# - Let's inspect example.html

# %% [markdown]
# ### Aquire Your Data

# %%
# read the HTML code for a web page and save as a string
with open('../../DAT-DC-10/data/example.html', 'rU') as f:
    html = f.read()

# %% [markdown]
# ### Look at / Explorre Your Data (html)

# %%
#print html

# %%
# convert HTML into a structured Soup object
from bs4 import BeautifulSoup
b = BeautifulSoup(html, 'html.parser')

# %%
# print out the object
#print b
#print b.prettify()

# %% [markdown]
# #### 'find' method returns the first matching Tag (and everything inside of it)

# %%
b.find(name='body')
b.find(name='h1')
# Out:
# <h1 id="main">DAT10 Class 6</h1>

# %%
# Tags allow you to access the 'inside text'
b.find(name='h1').text
# Out:
# u'DAT10 Class 6'

# %%
# Tags also allow you to access their attributes
b.find(name='h1')['id']
# Out:
# u'main'

# %% [markdown]
# #### 'find_all' method is useful for finding all matching Tags

# %%
test = b.find_all(name='p')    # returns a ResultSet (like a list of Tags)

# %% [markdown]
# ### Quiz: What is the datatype returned by 'find_all'? What kinds of operations can we do on that datatype?

# %%
type(test)
# Out:
# bs4.element.ResultSet

# %%
tag1 = test[0]

# %%
tag1.contents
# Out:
# [u'First, we are covering APIs, which are useful for getting data.']

# %% [markdown]
# Hint: ResultSets can be sliced

# %%
#len(b.find_all(name='p'))
#b.find_all(name='p')[0]
#b.find_all(name='p')[0].text
b.find_all(name='p')[0]['id']
# Out:
# u'api'

# %%
# iterate over a ResultSet
results = b.find_all(name='p')
for tag in results:
    print tag.text
# Out:
# First, we are covering APIs, which are useful for getting data.
# Then, we are covering web scraping, which is a more flexible way to get data.
# Finally, I will ask you to fill out yet another feedback form!
# Here are some helpful API resources:
# Here are some helpful web scraping resources:

# %%
print "\n".join(tag.text for tag in results if len(tag.text) > 0)
# Out:
# First, we are covering APIs, which are useful for getting data.
# Then, we are covering web scraping, which is a more flexible way to get data.
# Finally, I will ask you to fill out yet another feedback form!
# Here are some helpful API resources:
# Here are some helpful web scraping resources:

# %%
print "\n".join(list_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ac42e71cce25> in <module>()
# ----> 1 print "\n".join(list_text)
#
# NameError: name 'list_text' is not defined

# %% [markdown]
# ### Quiz: How would you write the above as a list comprenhension?

# %% [markdown]
# ### Limit search by Tag attribute

# %%
b.find(name='p', attrs={'id':'scraping'})
# Out:
# <p class="topic" id="scraping">Then, we are covering web scraping, which is a more flexible way to get data.</p>

# %%
#b.find_all(name='p', attrs={'class':'topic'})
b.find_all(attrs={'class':'topic'})
# Out:
# [<p class="topic" id="api">First, we are covering APIs, which are useful for getting data.</p>,
#  <p class="topic" id="scraping">Then, we are covering web scraping, which is a more flexible way to get data.</p>,
#  <p class="topic" id="feedback">Finally, I will ask you to fill out yet another feedback form!</p>]

# %% [markdown]
# ### Limit search to specific sections

# %%
#b.find_all(name='li')
b.find(name='ul', attrs={'id':'scraping'}).find_all(name='li')
# Out:
# [<li>Web scraping resource 1</li>, <li>Web scraping resource 2</li>]

# %% [markdown]
# ## In Class Exercise

# %% [markdown]
# 1) Find the 'h2' tag and then print its text

# %%
b.find(name='h2').text
# Out:
# u'Resource List'

# %%
print ", ".join(tag.text for tag in tagList)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-79280d7bd265> in <module>()
# ----> 1 print ", ".join(tag.text for tag in tagList)
#
# NameError: name 'tagList' is not defined

# %% [markdown]
# 2) Find the 'p' tag with an 'id' value of 'feedback' and then print its text

# %%
b.find(name='p', attrs={'id':'feedback'}).text
# Out:
# u'Finally, I will ask you to fill out yet another feedback form!'

# %% [markdown]
# 3) Find the first 'p' tag and then print the value of the 'id' attribute

# %%
b.find(name='p')['id']
# Out:
# u'api'

# %% [markdown]
# 4) Print the text of all four resources

# %%
", ".join(tag.text for tag in b.find_all(name='li'))
# Out:
# u'API resource 1, API resource 2, Web scraping resource 1, Web scraping resource 2'

# %% [markdown]
# 5) Using a list comprehension can you extract the text of only the API resources?

# %%
print "\n".join(tag.text for tag in b.find(name='ul', attrs={'id':'api'}).find_all(name='li'))
# Out:
# API resource 1
# API resource 2

# %% [markdown]
# ### Tool: Selector Gadget
# http://selectorgadget.com/

# %% [markdown]
# ## Scraping Craigslist

# %% [markdown]
# #### First open your browser and look at the website and the html structure
#
# http://www.imdb.com/title/tt0111161/

# %% [markdown]
# #### Get the HTML from the Shawshank Redemption page

# %%
import requests
r = requests.get('http://www.imdb.com/title/tt0111161/')

# %% [markdown]
# #### What is r? What can we do with it?

# %%
type(r)
# Out:
# requests.models.Response

# %%
r.
# Out:
#   File "<ipython-input-27-ea092d2967a4>", line 1
#     r.
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### convert HTML into Soup

# %%
b = BeautifulSoup(r.text, 'html.parser')
print b
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8">
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <script type="text/javascript">var ue_t0=window.ue_t0||+new Date();</script>
# <script type="text/javascript">
#                 var ue_mid = "A1EVAM02EL8SFB";
#                 var ue_sn = "www.imdb.com";
#                 var ue_furl = "fls-na.amazon.com";
#                 var ue_sid = "000-0000000-0000000";
#                 var ue_id = "1C6ED3N1MEXT51PTG99B";
#                 (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,i){var k={m:m,f:l,l:h,c:""+j,err:i,fromOnError:1,args:arguments};c.ueLogError(k);return false}b.skipTrace=1;e.onerror=b;function f(){c.uex("ld")}if(e.addEventListener){e.addEventListener("load",f,false)}else{if(e.attachEvent){e.attachEvent("onload",f)}}a.tag=d("tag");a.log=d("log");a.reset=d("rst");c.ue_csm=c;c.ue=a;c.ueLogError=d("err");c.ues=d("ues");c.uet=d("uet");c.uex=d("uex");c.uet("ue")})(window);(function(e,d){var a=e.ue||{};function c(g){if(!g){return}var f=d.head||d.getElementsByTagName("head")[0]||d.documentElement,h=d.createElement("script");h.async="async";h.src=g;f.insertBefore(h,f.firstChild)}function b(){var k=e.ue_cdn||"z-ecx.images-amazon.com",g=e.ue_cdns||"images-na.ssl-images-amazon.com",j="/images/G/01/csminstrumentation/",h=e.ue_file||"ue-full-051542d0cfa6f645f8266601739de597._V1_.js",f,i;if(h.indexOf("NSTRUMENTATION_FIL")>=0){return}if("ue_https" in e){f=e.ue_https}else{f=e.location&&e.location.protocol=="https:"?1:0}i=f?"https://":"http://";i+=f?g:k;i+=j;i+=h;c(i)}if(!e.ue_inline){if(a.loadUEFull){a.loadUEFull()}else{b()}}a.uels=c;e.ue=a})(window,document);
#                 if (!('CS' in window)) { window.CS = {}; }
#                     window.CS.loginSecureHost = "https://secure.imdb.com";
#             </script>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>The Shawshank Redemption (1994) - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <link href="http://www.imdb.com/title/tt0111161/" rel="canonical"/>
# <meta content="http://www.imdb.com/title/tt0111161/" property="og:url"/>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_icon"] = new Date().getTime(); })(IMDbTimer);</script>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/images/safari-favicon-517611381._CB303901978_.svg" mask="" rel="icon" sizes="any">
# <link href="http://ia.media-imdb.com/images/G/01/imdb/images/favicon-2165806970._CB379387995_.ico" rel="icon" type="image/ico"/>
# <meta content="#000000" name="theme-color"/>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/images/desktop-favicon-2165806970._CB379390718_.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-4151659188._CB361295786_.png" rel="apple-touch-icon">
# <link href="http://ia.media-imdb.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-76x76-53536248._CB361295462_.png" rel="apple-touch-icon" sizes="76x76">
# <link href="http://ia.media-imdb.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-120x120-2442878471._CB361295428_.png" rel="apple-touch-icon" sizes="120x120">
# <link href="http://ia.media-imdb.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-152x152-1475823641._CB361295368_.png" rel="apple-touch-icon" sizes="152x152">
# <link href="http://ia.media-imdb.com/images/G/01/imdb/images/imdbsearch-3349468880._CB379388505_.xml" rel="search" title="IMDb" type="application/opensearchdescription+xml"/>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_icon"] = new Date().getTime(); })(IMDbTimer);</script>
# <link href="http://ia.media-imdb.com/images/M/MV5BODU4MjU4NjIwNl5BMl5BanBnXkFtZTgwMDU2MjEyMDE@._V1_UY1200_CR88,0,630,1200_AL_.jpg" rel="image_src">
# <meta content="http://ia.media-imdb.com/images/M/MV5BODU4MjU4NjIwNl5BMl5BanBnXkFtZTgwMDU2MjEyMDE@._V1_UY1200_CR88,0,630,1200_AL_.jpg" property="og:image"/>
# <meta content="video.movie" property="og:type"/>
# <meta content="115109575169727" property="fb:app_id"/>
# <meta content="The Shawshank Redemption (1994)" property="og:title"/>
# <meta content="IMDb" property="og:site_name"/>
# <meta content="The Shawshank Redemption (1994) - IMDb" name="title"/>
# <meta content="Directed by Frank Darabont.  With Tim Robbins, Morgan Freeman, Bob Gunton, William Sadler. Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency." name="description"/>
# <meta content="Directed by Frank Darabont.  With Tim Robbins, Morgan Freeman, Bob Gunton, William Sadler. Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency." property="og:description"/>
# <meta content="Reviews, Showtimes, DVDs, Photos, Message Boards, User Ratings, Synopsis, Trailers, Credits" name="keywords"/>
# <meta content="1C6ED3N1MEXT51PTG99B" name="request_id"/>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_css"] = new Date().getTime(); })(IMDbTimer);</script>
# <!-- h=ics-1e-c3-2xl-i-8afac234.us-east-1 -->
# <link href="http://ia.media-imdb.com/images/G/01/imdb/css/collections/title-flat-v2-1732428637._CB285668695_.css" rel="stylesheet" type="text/css"/>
# <noscript>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/css/wheel/nojs-2827156349._CB318528195_.css" rel="stylesheet" type="text/css">
# </link></noscript>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_css"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_ads"] = new Date().getTime(); })(IMDbTimer);</script>
# <script type="text/javascript">
#             // ensures js doesn't die if ads service fails.
#             // Note that we need to define the js here, since ad js is being rendered inline after this.
#             (function(f) {
#                 // Fallback javascript, when the ad Service call fails.
#
#                 if((window.csm == null || window.generic == null || window.consoleLog == null)) {
#                     if (window.console && console.log) {
#                         console.log("one or more of window.csm, window.generic or window.consoleLog has been stubbed...");
#                     }
#                 }
#
#                 window.csm = window.csm || { measure:f, record:f, duration:f, listen:f, metrics:{} };
#                 window.generic = window.generic || { monitoring: { start_timing: f, stop_timing: f } };
#                 window.consoleLog = window.consoleLog || f;
#             })(function() {});
#         </script>
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_head_delivery_finished');
#     }
#   </script>
# </link></link></link></link></link></link></meta></meta></head>
# <body class="fixed" id="styleguide-v2">
# <script>
#     if (typeof uet == 'function') {
#       uet("bb");
#     }
# </script>
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_body_delivery_started');
#     }
#   </script>
# <div id="wrapper">
# <div class="redesign" id="root">
# <script>
#     if (typeof uet == 'function') {
#       uet("ns");
#     }
# </script>
# <div class="navbarSprite" id="nb20">
# <div id="supertab">
# <!-- no content received for slot: top_ad -->
# </div>
# <div class="navbarSprite" id="navbar">
# <noscript>
# <link href="http://ia.media-imdb.com/images/G/01/imdb/css/site/consumer-navbar-no-js-3652782989._CB318528046_.css" rel="stylesheet" type="text/css"/>
# </noscript>
# <!--[if IE]><link rel="stylesheet" type="text/css" href="http://ia.media-imdb.com/images/G/01/imdb/css/site/consumer-navbar-ie-2133976414._CB318528041_.css"><![endif]-->
# <span id="home_img_holder">
# <a class="navbarSprite" href="/?ref_=nv_home" id="home_img" title="Home"></a> <span class="alt_logo">
# <a href="/?ref_=nv_home" title="Home">IMDb</a>
# </span>
# </span>
# <form action="/find" class="nav-searchbar-inner" id="navbar-form" method="get">
# <div id="nb_search">
# <noscript><div id="more_if_no_javascript"><a href="/search/">More</a></div></noscript>
# <button class="primary btn" id="navbar-submit-button" type="submit"><div class="magnifyingglass navbarSprite"></div></button>
# <input name="ref_" type="hidden" value="nv_sr_fn"/>
# <input autocomplete="off" id="navbar-query" name="q" placeholder="Find Movies, TV shows, Celebrities and more..." type="text" value="">
# <div class="quicksearch_dropdown_wrapper">
# <select class="quicksearch_dropdown navbarSprite" id="quicksearch" name="s" onchange="jumpMenu(this); suggestionsearch_dropdown_choice(this);">
# <option value="all">All</option>
# <option value="tt">Titles</option>
# <option value="ep">TV Episodes</option>
# <option value="nm">Names</option>
# <option value="co">Companies</option>
# <option value="kw">Keywords</option>
# <option value="ch">Characters</option>
# <option value="qu">Quotes</option>
# <option value="bi">Bios</option>
# <option value="pl">Plots</option>
# </select>
# </div>
# <div id="navbar-suggestionsearch"></div>
# </input></div>
# </form>
# <div id="megaMenu">
# <ul class="main_nav" id="consumer_main_nav">
# <li class="spacer"></li>
# <li class="css_nav_item" id="navTitleMenu">
# <p class="navCategory">
# <a href="/movies-in-theaters/?ref_=nv_tp_inth_1">Movies</a>,
#                 <a href="/chart/toptv/?ref_=nv_tp_tv250_2">TV</a><br/>
#                 &amp; <a href="/showtimes/?ref_=nv_tp_sh_3">Showtimes</a></p>
# <span class="downArrow"></span>
# <div class="sub_nav" id="navMenu1">
# <div id="titleAd"></div>
# <div class="subNavListContainer">
# <h5>MOVIES</h5>
# <ul>
# <li><a href="/movies-in-theaters/?ref_=nv_mv_inth_1">In Theaters</a></li>
# <li><a href="/showtimes/?ref_=nv_mv_sh_2">Showtimes &amp; Tickets</a></li>
# <li><a href="/trailers/?ref_=nv_mv_tr_3">Latest Trailers</a></li>
# <li><a href="/movies-coming-soon/?ref_=nv_mv_cs_4">Coming Soon</a></li>
# <li><a href="/calendar/?ref_=nv_mv_cal_5">Release Calendar</a></li>
# <li><a href="/chart/top?ref_=nv_mv_250_6">Top Rated Movies</a></li>
# <li><a href="/chart/moviemeter?ref_=nv_mv_mpm_7">Most Popular Movies</a></li>
# </ul>
# <h5>CHARTS &amp; TRENDS</h5>
# <ul>
# <li><a href="/chart/?ref_=nv_ch_cht_1">Box Office</a></li>
# <li><a href="/search/title?count=100&amp;groups=oscar_best_picture_winners&amp;sort=year,desc&amp;ref_=nv_ch_osc_2
a></p>
# <span class="downArrow"></span>
# <div class="sub_nav" id="navMenu3">
# <div id="latestHeadlines">
# <div class="subNavListContainer">
# <h5>LATEST HEADLINES</h5>
# <ul>
# <li itemprop="headline">
# <a href="/news/ni59313100/?ref_=nv_nw_tn_1"> 'Star Wars: The Force Awakens' Shatters Opening Day Record
# </a><br/>
# <span class="time">19 December 2015 3:28 PM, UTC</span>
# </li>
# <li itemprop="headline">
# <a href="/news/ni59313091/?ref_=nv_nw_tn_2"> ‘Star Wars’ Explodes at Global Box Office With $250 Million
# </a><br/>
# <span class="time">19 December 2015 4:25 PM, UTC</span>
# </li>
# <li itemprop="headline">
# <a href="/news/ni59312365/?ref_=nv_nw_tn_3"> Tom Hanks’ ‘Sully’ Biopic of Heroic Pilot Gets Release Date
# </a><br/>
# <span class="time">19 December 2015 6:21 AM, UTC</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="subNavListContainer">
# <h5>NEWS</h5>
# <ul>
# <li><a href="/news/top?ref_=nv_nw_tp_1">Top News</a></li>
# <li><a href="/news/movie?ref_=nv_nw_mv_2">Movie News</a></li>
# <li><a href="/news/tv?ref_=nv_nw_tv_3">TV News</a></li>
# <li><a href="/news/celebrity?ref_=nv_nw_cel_4">Celebrity News</a></li>
# <li><a href="/news/indie?ref_=nv_nw_ind_5">Indie News</a></li>
# </ul>
# <h5>COMMUNITY</h5>
# <ul>
# <li><a href="/boards/?ref_=nv_cm_bd_1">Message Boards</a></li>
# <li><a href="/czone/?ref_=nv_cm_cz_2">Contributor Zone</a></li>
# <li><a href="/poll/?ref_=nv_cm_pl_3">Polls</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="spacer"></li>
# <li class="css_nav_item" id="navWatchlistMenu">
# <p class="navCategory singleLine watchlist">
# <a href="/list/watchlist?ref_=nv_wl_all_0">Watchlist</a>
# </p>
# <span class="downArrow"></span>
# <div class="sub_nav" id="navMenu4">
# <h5>
#             YOUR WATCHLIST
#     </h5>
# <ul id="navWatchlist">
# </ul>
# <script>
#     if (!('imdb' in window)) { window.imdb = {}; }
#     window.imdb.watchlistTeaserData = [
#                 {
#                         href : "/list/watchlist",
#                 src : "http://ia.media-imdb.com/images/G/01/imdb/images/navbar/watchlist_slot1_logged_out-1670046337._CB306318084_.jpg"
#                 },
#                 {
#                     href : "/search/title?count=100&title_type=feature,tv_series",
#                 src : "http://ia.media-imdb.com/images/G/01/imdb/images/navbar/watchlist_slot2_popular-4090757197._CB306318127_.jpg"
#                 },
#                 {
#                     href : "/chart/top",
#                 src : "http://ia.media-imdb.com/images/G/01/imdb/images/navbar/watchlist_slot3_top250-575799966._CB306318332_.jpg"
#                 }
#     ];
#     </script>
# </div>
# </li>
# <li class="spacer"></li>
# </ul>
# <script>
# if (!('imdb' in window)) { window.imdb = {}; }
# window.imdb.navbarAdSlots = {
#     titleAd : {
#     },
#     nameAd : {
#     }
# }
# </script>
# </div>
# <div id="nb_extra">
# <ul class="main_nav" id="nb_extra_nav">
# <li class="css_nav_item" id="navProMenu">
# <p class="navCategory">
# <a href="http://pro.imdb.com/signup/index.html?rf=cons_nb_hm&amp;ref_=cons_nb_hm"> <img alt="IMDbPro Menu" src="http://ia.media-imdb.com/images/G/01/imdb/images/navbar/imdbpro_logo_nb-720143162._CB306318304_.png"/>
# </a> </p>
# <span class="downArrow"></span>
# <div class="sub_nav" id="navMenuPro">
# <a href="http://pro.imdb.com/signup/index.html?rf=cons_nb_hm&amp;ref_=cons_nb_hm" id="proLink"> <div id="proAd">
# <script>
# if (!('imdb' in window)) { window.imdb = {}; }
# window.imdb.proMenuTeaser = {
# imageUrl : "http://ia.media-imdb.com/images/G/01/imdb/images/navbar/imdbpro_menu_user-2082544740._CB306318138_.jpg"
# };
# </script>
# </div>
# <div class="subNavListContainer">
# <img alt="Go to IMDbPro" src="http://ia.media-imdb.com/images/G/01/imdb/images/navbar/imdbpro_logo_menu-2185879182._CB306318245_.png" title="Go to IMDbPro"/>
# <h5>GET INFORMED</h5>
# <p>Industry information at your fingertips</p>
# <h5>GET CONNECTED</h5>
# <p>Over 200,000 Hollywood insiders</p>
# <h5>GET DISCOVERED</h5>
# <p>Enhance your IMDb Page</p>
# <p><strong>Go to IMDbPro »</strong></p>
# </div>
# </a> </div>
# </li>
# <li class="spacer"><span class="ghost">|</span></li>
# <li>
# <a href="/help/?ref_=nb_hlp">Help</a>
# </li>
# <li class="social">
# <a href="/offsite/?page-action=fol_fb&amp;token=BCYmQpP_fE3EGaD04NiiqwfsTkXN0MOXSorbVMSKzR3znA2jj_T2n6ktElZLLYfiI-FH9cjDTyJQ%0D%0AVLDYEw_TYr1v9DPqKU3mI_ploYOpX8aXGD-SBdplW_RyJO_F_RZYSP7YKsn92R_ss4Lz5AC-K_BK%0D%0AhiTJgj0ddWKKCZlbxn0U-3SVKM10Lrrycq_ZBZYj__0fnbV8liDQhtgkssmRpq-QwA%0D%0A&amp;ref_=tt_nv_fol_fb" itemprop="url" target="_blank" title="Follow IMDb on Facebook"> <span class="desktop-sprite follow-facebook"></span>
# </a>
# <a href="/offsite/?page-action=fol_tw&amp;token=BCYo-ZtTChr6Nd_JrICSB1dKoUkPqUcQ8ZeGaT_1NSYF9jg7CCOPPrHMSKyem2ILTX9NTqsKr0tt%0D%0AMGE_re8sJ7HhVhN433J0An3QAgguRJMjXv1rp2hk_UyEYfPnwpUzpoDrCEAmBkibz2daqaUCkpR6%0D%0AbEYwPdt8IPujoesbOWsaSQJLIFzDxQLA2Uvd4a923rgxP69kisecsHiK6vwRMMw2Ug%0D%0A&amp;ref_=tt_nv_fol_tw" itemprop="url" target="_blank" title="Follow IMDb on Twitter"> <span class="desktop-sprite follow-twitter"></span>
# </a>
# <a href="/offsite/?page-action=fol_inst&amp;token=BCYu2fK0mkyUHM03P70HNAPafoCGXCaleSyEam8-zwqltuwHMKItqjipjaFQclxe2TwBXazUyX_f%0D%0ANGvuYCTaQh-eLHxjClY5jZHsV_IRZGNc-T_Z4YTjiq-z6TLY2IGbDiZFt3qkjQCgHJm8i8KxaZk-%0D%0AtIG93sIgH-otlDiPn_8gOOlp4Z8vPIpY9jl_xhKuUxGnsquhXZIQ5QJFaK2OMapcIA%0D%0A&amp;ref_=tt_nv_fol_inst" itemprop="url" target="_blank" title="Follow IMDb on Instagram"> <span class="desktop-sprite follow-instagram"></span>
# </a>
# </li>
# </ul>
# </div>
# <div id="nb_personal">
# <ul class="main_nav" id="consumer_user_nav">
# <li class="css_nav_menu" id="navUserMenu">
# <p class="navCategory singleLine">
# <a href="/register/login?ref_=nv_usr_lgin_1" id="nblogin" rel="login">Login</a>
# </p>
# <span class="downArrow"></span>
# <div class="sub_nav">
# <div class="subNavListContainer">
# <br/>
# <ul>
# <li>
# <a href="https://secure.imdb.com/register-imdb/form-v2?ref_=nv_usr_reg_2">Register</a>
# </li>
# <li>
# <a href="/register/login?ref_=nv_usr_lgin_3" id="nblogin" rel="login">Login</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- no content received for slot: navstrip -->
# <!-- no content received for slot: injected_navstrip -->
# <script>
#     if (typeof uet == 'function') {
#       uet("ne");
#     }
# </script>
# <div class="pagecontent" id="pagecontent" itemscope="" itemtype="http://schema.org/Movie">
# <!-- no content received for slot: injected_billboard -->
# <!-- no content received for slot: navboard -->
# <div class="flatland" id="content-2-wide">
# <div class="main" id="main_top">
# <div class="title-overview">
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_TitleOverviewWidget_started');
#     }
#   </script>
# <div class="heroic-overview" id="title-overview-widget">
# <div class="message_box">
# <div class="hidden seen-errors error">
# <h2>There was an error trying to load your 'seen' status for this title.</h2>
# <p>Some parts of this page won't work property. Please reload or try later.</p>
# </div>
# </div>
# <div class="vital">
# <div class="subnav" id="quicklinksBar">
# <div id="quicklinksMainSection">
# <a class="quicklink" href="/title/tt0111161/fullcredits?ref_=tt_ql_1">FULL CAST &amp; CREW</a> <span class="ghost">|</span>
# <a class="quicklink" href="/title/tt0111161/trivia?ref_=tt_ql_2">TRIVIA</a> <span class="ghost">|</span>
# <a class="quicklink" href="/title/tt0111161/reviews?ref_=tt_ql_3">USER REVIEWS</a> <span class="ghost">|</span>
# <a class="quicklink" href="http://pro.imdb.com/title/tt0111161?rf=cons_tt_contact&amp;ref_=cons_tt_contact">PRO</a>
# <span class="ghost">|</span>
# <span class="show_more quicklink">
#             MORE<span class="titleOverviewSprite quicklinksArrowUp"></span>
# </span>
# <span class="show_less quicklink" style="display:none">
#            LESS<span class="titleOverviewSprite quicklinksArrowDown"></span>
# </span>
# </div>
# <span class="titleOverviewShareButton launch-share-popover quicklink">SHARE</span>
# <div id="share-popover">
# <a class="close-popover" href="#">X</a>
# <h4>Share</h4>
# <a class="facebook" href="http://www.facebook.com/sharer.php?u=http%3A%2F%2Fwww.imdb.com%2Ftitle%2Ftt0111161%2F%3Fref_%3Dext_shr_fb_tt" onclick="window.open(&quot;http://www.facebook.com/sharer.php?u=http%3A%2F%2Fwww.imdb.com%2Ftitle%2Ftt0111161%2F%3Fref_%3Dext_shr_fb_tt&quot;, 'newWindow', 'width=626,height=436'); return false;" target="_blank" title="Share on Facebook"><div class="option facebook">
# <span class="titlePageSprite share_facebook"></span>
# <div>Facebook</div>
# </div></a>
# <a class="twitter" href="http://twitter.com/intent/tweet?text=The%20Shawshank%20Redemption%20(14%20October%201994%20(USA))%20-%20imdb.com%2Ftitle%2Ftt0111161%2F%3Fref_%3Dext_shr_tw_tt" onclick="window.open(&quot;http://twitter.com/intent/tweet?text=The%20Shawshank%20Redemption%20(14%20October%201994%20(USA))%20-%20imdb.com%2Ftitle%2Ftt0111161%2F%3Fref_%3Dext_shr_tw_tt&quot;, 'newWindow', 'width=815,height=436'); return false;" target="_blank" title="Share on Twitter"><div class="option twitter">
# <span class="titlePageSprite share_twitter"></span>
# <div>Twitter</div>
# </div></a>
# <a class="" href="mailto:?subject=IMDb%3A%20The%20Shawshank%20Redemption%20(14%20October%201994%20(USA))&amp;body=IMDb%3A%20The%20Shawshank%20Redemption%20(14%20October%201994%20(USA))%0ATwo%20imprisoned%20men%20bond%20over%20a%20number%20of%20years%2C%20finding%20solace%20and%20eventual%20redemption%20through%20acts%20of%20common%20decency.%0Ahttp%3A%2F%2Fwww.imdb.com%2Ftitle%2Ftt0111161%2F%3Fref_%3Dext_shr_eml_tt" title="Share by e-mail"><div class="option email">
# <span class="titlePageSprite share_email"></span>
# <div>E-mail</div>
# </div></a>
# <a class="open-checkin-popover" href="#">
# <div class="option checkin">
# <span class="titlePageSprite share_checkin"></span>
# <div>Check in</div>
# </div>
# </a>
# </div>
# <div id="share-checkin">
# <div class="add_to_checkins" data-const="tt0111161" data-lcn="title-maindetails">
# <span class="btn2_wrapper"><a class="btn2 large btn2_text_on disabled checkins_action_btn" onclick=""><span class="btn2_glyph">0</span><span class="btn2_text">Check in</span></a></span> <div class="popup checkin-dialog">
# <a class="small disabled close btn">X</a>
# <span class="beta">Beta</span>
# <span class="title">I'm Watching This!</span>
# <div class="body">
# <div class="info">Keep track of everything you watch; tell your friends.
#             </div>
# <div class="small message_box">
# <div class="hidden error"><h2>Error</h2> Please try again!</div>
# <div class="hidden success"><h2>Added to Your Check-Ins.</h2> <a href="/list/checkins">View</a></div>
# </div>
# <textarea data-msg="Enter a comment..."></textarea>
# <div class="share">
# <button class="large primary btn"><span>Check in</span></button>
# <!--
#                     Check-ins are more fun when<br>
#                     you <a href="/register/sharing">enable Facebook sharing</a>!
# -->
# </div>
# </div>
# </div>
# <input name="49e6c" type="hidden" value="da29">
# </input></div>
# </div>
# <div class="quicklinkSection" id="full_subnav" style="display:none">
# <div class="quicklinkSectionColumn">
# <div class="quicklinkGroup">
# <div class="quicklinkSectionHeader">DETAILS</div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/fullcredits?ref_=tt_ql_dt_1">Full Cast &amp; Crew</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/releaseinfo?ref_=tt_ql_dt_2">Release Dates</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/officialsites?ref_=tt_ql_dt_3">Official Sites</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/business?ref_=tt_ql_dt_4">Box Office/Business</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/companycredits?ref_=tt_ql_dt_5">Company Credits</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/locations?ref_=tt_ql_dt_6">Filming Locations</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/technical?ref_=tt_ql_dt_7">Technical Specs</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink quicklinkGray" href="/title/tt0111161/literature?ref_=tt_ql_dt_8">Literature</a> </div>
# </div>
# <div class="quicklinkGroup">
# <div class="quicklinkSectionHeader">TV</div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/tvschedule?ref_=tt_ql_tv_1">TV Schedule</a> </div>
# </div>
# </div>
# <div class="quicklinkSectionColumn">
# <div class="quicklinkGroup">
# <div class="quicklinkSectionHeader">STORYLINE</div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/taglines?ref_=tt_ql_stry_1">Taglines</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/plotsummary?ref_=tt_ql_stry_2">Plot Summary</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/synopsis?ref_=tt_ql_stry_3">Synopsis</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/keywords?ref_=tt_ql_stry_4">Plot Keywords</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/parentalguide?ref_=tt_ql_stry_5">Parents Guide</a> </div>
# </div>
# <div class="quicklinkGroup">
# <div class="quicklinkSectionHeader">RELATED ITEMS</div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/news?ref_=tt_ql_rel_1">NewsDesk</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink quicklinkGray" href="/showtimes/title/tt0111161?ref_=tt_ql_rel_2">Showtimes</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/externalsites?ref_=tt_ql_rel_3">External Sites</a> </div>
# </div>
# </div>
# <div class="quicklinkSectionColumn">
# <div class="quicklinkGroup">
# <div class="quicklinkSectionHeader">OPINION</div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/awards?ref_=tt_ql_op_1">Awards</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/faq?ref_=tt_ql_op_2">FAQ</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/reviews?ref_=tt_ql_op_3">User Reviews</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/ratings?ref_=tt_ql_op_4">User Ratings</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/externalreviews?ref_=tt_ql_op_5">External Reviews</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/criticreviews?ref_=tt_ql_op_6">Metacritic Reviews</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/board/?ref_=tt_ql_op_7">Message Board</a> </div>
# </div>
# <div class="quicklinkGroup">
# <div class="quicklinkSectionHeader">PHOTO &amp; VIDEO</div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/mediaindex?ref_=tt_ql_pv_1">Photo Gallery</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/videogallery?ref_=tt_ql_pv_2">Trailers and Videos</a> </div>
# </div>
# </div>
# <div class="quicklinkSectionColumn">
# <div class="quicklinkGroup">
# <div class="quicklinkSectionHeader">DID YOU KNOW?</div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/trivia?ref_=tt_ql_trv_1">Trivia</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/goofs?ref_=tt_ql_trv_2">Goofs</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/crazycredits?ref_=tt_ql_trv_3">Crazy Credits</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/quotes?ref_=tt_ql_trv_4">Quotes</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/alternateversions?ref_=tt_ql_trv_5">Alternate Versions</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/movieconnections?ref_=tt_ql_trv_6">Connections</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="/title/tt0111161/soundtrack?ref_=tt_ql_trv_7">Soundtracks</a> </div>
# </div>
# <div class="quicklinkGroup">
# <div class="quicklinkSectionHeader">PROFESSIONAL SERVICES</div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="http://pro.imdb.com/title/tt0111161?ref_=tt_ql_pro_1">Get more at IMDbPro</a> </div>
# <div class="quicklinkSectionItem">
# <a class="quicklink" href="https://secure.imdb.com/store/photos/?ref_=tt_ql_pro_2">Add posters &amp; stills to this title</a> </div>
# </div>
# </div>
# </div>
# </div>
# <div class="title_block">
# <div class="title_bar_wrapper">
# <div class="ratings_wrapper">
# <div class="imdbRating" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating">
# <div class="ratingValue">
# <strong title="9.3 based on 1,573,023 votes"><span itemprop="ratingValue">9.3</span></strong><span class="grey">/</span><span class="grey" itemprop="bestRating">10</span> </div>
# <a href="/title/tt0111161/ratings?ref_=tt_ov_rt"><span class="small" itemprop="ratingCount">1,573,023</span></a>
# <div class="hiddenImportant">
# <span itemprop="reviewCount">3,843 user</span>
# <span itemprop="reviewCount">194 critic</span>
# </div>
# </div>
# <input data-caller="tt_ov" id="seen-config" type="hidden"> <div class="seen-widget seen-widget-tt0111161 pending" data-titleid="tt0111161">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </input></div>
# <div class="titleBar">
# <div class="primary_ribbon">
# <div class="ribbonize" data-tconst="tt0111161"></div>
# <div class="wlb_dropdown_btn" data-caller-name="title" data-size="large" data-tconst="tt0111161" data-type="primary"></div>
# <div class="wlb_dropdown_list" style="display:none"></div>
# </div>
# <div class="title_wrapper">
# <h1 class="" itemprop="name">The Shawshank Redemption
#                    <span id="titleYear">(<a href="/year/1994/?ref_=tt_ov_inf">1994</a>)
#                    </span>
# </h1>
# <div class="subtext">
# <meta content="R" itemprop="contentRating">R
# <span class="ghost">|</span> <time datetime="PT142M" itemprop="duration">
#                         2h 22min
#                     </time>
# <span class="ghost">|</span>
# <a href="/genre/Crime?ref_=tt_ov_inf"><span class="itemprop" itemprop="genre">Crime</span></a>,
# <a href="/genre/Drama?ref_=tt_ov_inf"><span class="itemprop" itemprop="genre">Drama</span></a>
# <span class="ghost">|</span>
# <a href="/title/tt0111161/releaseinfo?ref_=tt_ov_inf" title="See more release dates">14 October 1994 (USA)
# <meta content="1994-10-14" itemprop="datePublished"/>
# </a> </meta></div>
# </div>
# </div>
# </div>
# </div>
# <div class="slate_wrapper">
# <div class="poster">
# <a href="/media/rm3597327872/tt0111161?ref_=tt_ov_i"> <img alt="The Shawshank Redemption Poster" itemprop="image" src="http://ia.media-imdb.com/images/M/MV5BODU4MjU4NjIwNl5BMl5BanBnXkFtZTgwMDU2MjEyMDE@._V1_UX182_CR0,0,182,268_AL_.jpg" title="The Shawshank Redemption Poster"/>
# </a> </div>
# <div class="slate">
# <a class="slate_button prevent-ad-overlay video-colorbox" data-context="imdb" data-refsuffix="tt_ov_vi" data-tconst="tt0111161" data-type="recommends" data-video="videoSlate.getVideoId()" href="/video/imdb/vi3877612057?ref_=tt_ov_vi" itemprop="trailer"> <img alt="Trailer" itemprop="image" src="http://ia.media-imdb.com/images/M/MV5BNjQ2NDA3MDcxMF5BMl5BanBnXkFtZTgwMjE5NTU0NzE@._V1_CR0,60,640,360_AL_UX477_CR0,0,477,268_AL_.jpg" title="Trailer"/>
# <div class="slate_fade_top"></div>
# <div class="slate_fade_bottom"></div>
# </a> <div class="caption">
# <div style="float: left;">2:11 <span class="ghost">|</span> Trailer</div>
# <div style="float: right;"> <a href="/title/tt0111161/videogallery?ref_=tt_ov_vi_sm">2 VIDEOS</a>
# <span class="ghost">|</span> <a href="/title/tt0111161/mediaindex?ref_=tt_ov_mi_sm">31 IMAGES</a>
# </div>
# <div style="clear: both;"></div>
# </div>
# </div>
# </div>
# </div>
# <div>
# <a name="slot_center-2"></a>
# <div class="article">
# <script type="text/javascript">if(typeof(uet)==='function'){uet('bb','TitleWatchBar',{wb:1});}</script>
# <span class="ab_widget">
# <div class="watchbar2 article">
# <div class="showtime full-table">
# <div class="winner-option watch-option " data-href="/offsite/?page-action=watch-aiv&amp;token=BCYg-q610eWVaHRzDTjwwBwjnx5A2DJriiMd7JUBqBQ_6qXPOTSt_UVxv1Sm5u3mYUmvZu4B6K-g%0D%0AYNpHmtuIkgjupJdnYVxJz-_t6-Ceb812QtfvqjSgqhpNerlPibb78W8bXogaFn_XgMPLLhNBTrg3%0D%0ALMwE_duUUZf8QrANjzEU6H-nXPPA2A4btbwaeLuD4A94Q7wwpCFPI-EER_fbO8b9DSwPz6nyCZuG%0D%0ARzW8O2R-erxORaJR77Yb-btGo1R6m6PE%0D%0A&amp;ref_=tt_wbr_aiv" data-offsite="1" title="Watch Now">
# <div class="watch-icon winner provider amazon-instant-video" id="watchbar2">
# </div>
# <div class="info table-cell">
# <h2>
# <a class="segment-link " href="/offsite/?page-action=watch-aiv&amp;token=BCYg-q610eWVaHRzDTjwwBwjnx5A2DJriiMd7JUBqBQ_6qXPOTSt_UVxv1Sm5u3mYUmvZu4B6K-g%0D%0AYNpHmtuIkgjupJdnYVxJz-_t6-Ceb812QtfvqjSgqhpNerlPibb78W8bXogaFn_XgMPLLhNBTrg3%0D%0ALMwE_duUUZf8QrANjzEU6H-nXPPA2A4btbwaeLuD4A94Q7wwpCFPI-EER_fbO8b9DSwPz6nyCZuG%0D%0ARzW8O2R-erxORaJR77Yb-btGo1R6m6PE%0D%0A&amp;ref_=tt_wbr_aiv&amp;pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2279427422&amp;pf_rd_r=1C6ED3N1MEXT51PTG99B&amp;pf_rd_s=center-2&amp;pf_rd_t=15021&amp;pf_rd_i=tt0111161" target="_blank"> Watch Now
# </a> </h2>
# <p>
#
#             From $2.99 on
# Amazon Video                </p>
# </div>
# </div>
# <script type="text/javascript">
#         var xmlhttp = new XMLHttpRequest();
#         xmlhttp.open("POST","/tr/",true);
#         xmlhttp.setRequestHeader("Content-type","application/x-www-form-urlencoded");
#         xmlhttp.send("ref_=tt_wbr_aiv&pt=title&spt=main&pageAction=showing-aiv&ht=actionOnly");
#     </script>
# <div class="watch-option secondary-watch-option " data-href="/title/tt0111161/tvschedule?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2279427422&amp;pf_rd_r=1C6ED3N1MEXT51PTG99B&amp;pf_rd_s=center-2&amp;pf_rd_t=15021&amp;pf_rd_i=tt0111161&amp;ref_=tt_wbr_tv" data-optiontype="tv" title="On TV">
# <div class="watch-icon tv"></div>
# <div class="secondary-info">ON TV</div>
# </div>
# <div class="watch-option secondary-watch-option " data-href="/offsite/?page-action=watch-amazon&amp;token=BCYge-_tLSITRUZ-JwAzyt52NXvjxgfKwEYmDSym0xYyiE_Q-T6qW2hduI8RSZQ2dwGwELzfZ-O4%0D%0A_ZQsHjp7-BlAHK5xjSx2QuQLwcwFr1bQVrhE5O6_uLQm26z8c7eJECMPpM0IStDoj84JUpLr8oTS%0D%0ATpXmdGt_tUJeS9dFejyjR2kosoB224kuMl14lkdNC_E4Y9eGWcvQAO63x1AFIaHiu9YaRXdBUUTT%0D%0AboeKZJHljVyBgVtGRKFG1N3QX8Zq2tAl%0D%0A&amp;ref_=tt_wbr_amazon" data-optiontype="physical" title="On Disc">
# <div class="watch-icon physical"></div>
# <div class="secondary-info">ON DISC</div>
# </div>
# <div class="watch-option secondary-watch-option has-watchoptions" data-href="/watch/_ajax/box/tt0111161?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2279427422&amp;pf_rd_r=1C6ED3N1MEXT51PTG99B&amp;pf_rd_s=center-2&amp;pf_rd_t=15021&amp;pf_rd_i=tt0111161&amp;ref_=tt_wbr_sm#watchoptions" title="All Watch Options">
# <div class="watch-icon all"></div>
# <div class="secondary-info">ALL</div>
# </div>
# </div>
# </div>
# </span>
# <script type="text/javascript">if(typeof(uet)==='function'){uet('be','TitleWatchBar',{wb:1});}</script>
# </div>
# <div class="plot_summary_wrapper">
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_TitlePlotAndCreditSummaryWidget_started');
#     }
#   </script>
# <div class="plot_summary ">
# <div class="summary_text" itemprop="description">
#                     Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.
#             </div>
# <div class="credit_summary_item">
# <h4 class="inline">Director:</h4>
# <span itemprop="director" itemscope="" itemtype="http://schema.org/Person">
# <a href="/name/nm0001104?ref_=tt_ov_dr" itemprop="url"><span class="itemprop" itemprop="name">Frank Darabont</span></a> </span>
# </div>
# <div class="credit_summary_item">
# <h4 class="inline">Writers:</h4>
# <span itemprop="creator" itemscope="" itemtype="http://schema.org/Person">
# <a href="/name/nm0000175?ref_=tt_ov_wr" itemprop="url"><span class="itemprop" itemprop="name">Stephen King</span></a> (short story "Rita Hayworth and Shawshank Redemption"),             </span>
# <span itemprop="creator" itemscope="" itemtype="http://schema.org/Person">
# <a href="/name/nm0001104?ref_=tt_ov_wr" itemprop="url"><span class="itemprop" itemprop="name">Frank Darabont</span></a> (screenplay)            </span>
# </div>
# <div class="credit_summary_item">
# <h4 class="inline">Stars:</h4>
# <span itemprop="actors" itemscope="" itemtype="http://schema.org/Person">
# <a href="/name/nm0000209?ref_=tt_ov_st_sm" itemprop="url"><span class="itemprop" itemprop="name">Tim Robbins</span></a>,             </span>
# <span itemprop="actors" itemscope="" itemtype="http://schema.org/Person">
# <a href="/name/nm0000151?ref_=tt_ov_st_sm" itemprop="url"><span class="itemprop" itemprop="name">Morgan Freeman</span></a>,             </span>
# <span itemprop="actors" itemscope="" itemtype="http://schema.org/Person">
# <a href="/name/nm0348409?ref_=tt_ov_st_sm" itemprop="url"><span class="itemprop" itemprop="name">Bob Gunton</span></a> </span>
# <span class="ghost">|</span>
# <a href="fullcredits?ref_=tt_ov_st_sm">See full cast &amp; crew</a> »
#     </div>
# </div>
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_TitlePlotAndCreditSummaryWidget_finished');
#     }
#   </script>
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_TitleReviewsAndPopularityWidget_started');
#     }
#   </script>
# <div class="titleReviewBar ">
# <div class="titleReviewBarItem">
# <a href="criticreviews?ref_=tt_ov_rt"> <div class="metacriticScore score_favorable titleReviewBarSubItem">
# <span>80</span>
# </div></a> <div class="titleReviewBarSubItem">
# <div><a href="criticreviews?ref_=tt_ov_rt">
# Metascore
# </a> </div>
# <div><span class="subText">
#                From <a href="http://www.metacritic.com" target="_blank">metacritic.com</a>
# </span>
# </div>
# </div>
# </div>
# <div class="divider"></div>
# <div class="titleReviewBarItem titleReviewbarItemBorder">
# <div>
#         Reviews
#         </div>
# <div>
# <span class="subText">
# <a href="reviews?ref_=tt_ov_rt">3,843 user</a>
# <span class="ghostText">|</span>
# <a href="externalreviews?ref_=tt_ov_rt">194 critic</a>
# </span>
# </div>
# </div>
# <div class="divider"></div>
# <div class="titleReviewBarItem">
# <div class="titleOverviewSprite popularityTrendDown"></div>
# <div class="titleReviewBarSubItem">
# <div>
#             Popularity
#             </div>
# <div>
# <span class="subText">
#                     119
#       (<span class="titleOverviewSprite popularityImageDown"></span> <span class="popularityDown">7</span>)
#                 </span>
# </div>
# </div>
# </div>
# </div>
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_TitleReviewsAndPopularityWidget_finished');
#     }
#   </script>
# </div>
# </div>
# </div>
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_TitleOverviewWidget_finished');
#     }
#   </script>
# </div>
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_atf_main');
#     }
#   </script>
# </div>
# <script>
#     if (typeof uet == 'function') {
#       uet("cf");
#     }
# </script>
# <script>
#     if (typeof uet == 'function') {
#       uet("af");
#     }
# </script>
# <div id="sidebar">
# <!-- no content received for slot: top_rhs -->
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_atf_sidebar');
#     }
#   </script>
# <a name="slot_right-3"></a>
# <div class="mini-article">
# <script type="text/javascript">if(typeof(uet)==='function'){uet('bb','NinjaWidget',{wb:1});}</script>
# <span class="ab_widget">
# <div class="ab_ninja">
# <span class="widget_header"> <span class="oneline"> <a href="/awards-central/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2331623622&amp;pf_rd_r=1C6ED3N1MEXT51PTG99B&amp;pf_rd_s=right-3&amp;pf_rd_t=15021&amp;pf_rd_i=tt0111161&amp;ref_=tt_ac_hd&amp;pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2331623622&amp;pf_rd_r=1C6ED3N1MEXT51PTG99B&amp;pf_rd_s=right-3&amp;pf_rd_t=15021&amp;pf_rd_i=tt0111161"> <h3>It's Awards Season on IMDb</h3> </a> </span> </span> <p class="blurb">Check out IMDb's full coverage of all the major awards events, including the <a href="/awards-central/golden-globes/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2331623622&amp;pf_rd_r=1C6ED3N1MEXT51PTG99B&amp;pf_rd_s=right-3&amp;pf_rd_t=15021&amp;pf_rd_i=tt0111161&amp;ref_=tt_ac_lk1">2016 Golden Globe Awards</a>.</p> <div class="widget_content no_inline_blurb"> <div class="widget_nested"> <div class="ninja_image_pack"> <div class="ninja_center"> <div class="ninja_image first_image last_image" style="width:100%;height:auto;"> <div style="width:100%;height:auto;margin:0 auto;"> <div class="widget_image"> <div class="image"> <a href="/awards-central/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2331623622&amp;pf_rd_r=1C6ED3N1MEXT51PTG99B&amp;pf_rd_s=right-3&amp;pf_rd_t=15021&amp;pf_rd_i=tt0111161&amp;ref_=tt_ac_i_1&amp;pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2331623622&amp;pf_rd_r=1C6ED3N1MEXT51PTG99B&amp;pf_rd_s=right-3&amp;pf_rd_t=15021&amp;pf_rd_i=tt0111161"> <img alt="Still of Cate Blanchett and Kyle Chandler in Carol (2015)" class="pri_image" data-src-x2="http://ia.media-imdb.com/images/M/MV5BMjM0MDI5NjE4OV5BMl5BanBnXkFtZTgwNTY3MTQ2NTE@._V1_SY525_CR44,0,700,525_AL_UY1050_UX1400_AL_.jpg" itemprop="image" src="http://ia.media-imdb.com/images/M/MV5BMjM0MDI5NjE4OV5BMl5BanBnXkFtZTgwNTY3MTQ2NTE@._V1_SY525_CR44,0,700,525_AL_.jpg" title="Still of Cate Blanchett and Kyle Chandler in Carol (2015)"/> </a> </div> </div> </div> </div> </div> </div> </div> </div> <p class="seemore"><a class="position_bottom supplemental" href="/awards-central/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2331623622&amp;pf_rd_r=1C6ED3N1MEXT51PTG99B&amp;pf_rd_s=right-3&amp;pf_rd_t=15021&amp;pf_rd_i=tt0111161&amp;ref_=tt_ac_sm&amp;pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2331623622&amp;pf_rd_r=1C6ED3N1MEXT51PTG99B&amp;pf_rd_s=right-3&amp;pf_rd_t=15021&amp;pf_rd_i=tt0111161">Visit our Awards Central section</a></p> </div>
# </span>
# <script type="text/javascript">if(typeof(uet)==='function'){uet('be','NinjaWidget',{wb:1});}</script>
# </div>
# <div class="aux-content-widget-2">
# <div class="social">
# <script type="text/javascript">generic.monitoring.start_timing("facebook_like_iframe");</script>
# <div class="social_networking_like">
# <iframe allowtransparency="allowTransparency" class="social-iframe" frameborder="0" height="65" id="iframe_like" name="fbLikeIFrame_0" ref="http://www.imdb.com/title/tt0111161/" scrolling="no" width="280"></iframe>
# </div>
# </div>
# </div>
# <!-- no content received for slot: rhs_cornerstone -->
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "RelatedNewsWidgetRHS", {wb: 1});
#     }
# </script>
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_RelatedNewsWidgetRHS_started');
#     }
#   </script>
# <div class="mini-article">
# <h3>Related News</h3>
# <div class="news_item odd">
# <span itemprop="headline">
# <a href="/title/tt0111161/news?ref_=tt_nwr_1#ni58935217">2016 Oscar Predictions: Best Original Score</a>
# </span>
# <br/><small>
# <span itemprop="datePublished">
#                                   17 December 2015 1:35 PM, -05:00
#                                 </span>
# <span class="ghost">|</span><span itemprop="provider">
# <a href="/news/ns0000139?ref_=tt_nwr_1">Indiewire</a>
# </span>
# </small>
# </div>
# <div class="news_item even">
# <span itemprop="headline">
# <a href="/title/tt0111161/news?ref_=tt_nwr_2#ni59301747">‘Imitation of Life,’ ‘Being There,’ ‘Ghostbusters,’ and More Added to National Film Registry</a>
# </span>
# <br/><small>
# <span itemprop="datePublished">
#                                   16 December 2015 11:06 AM, -05:00
#                                 </span>
# <span class="ghost">|</span><span itemprop="provider">
# <a href="/news/ns0005386?ref_=tt_nwr_2">The Film Stage</a>
# </span>
# </small>
# </div>
# <div class="news_item odd">
# <span itemprop="headline">
# <a href="/title/tt0111161/news?ref_=tt_nwr_3#ni59302255">New Official "Ghostbusters" Cast Photo</a>
# </span>
# <br/><small>
# <span itemprop="datePublished">
#                                   16 December 2015 10:57 AM, -05:00
#                                 </span>
# <span class="ghost">|</span><span itemprop="provider">
# <a href="/news/ns0000799?ref_=tt_nwr_3">Dark Horizons</a>
# </span>
# </small>
# </div>
# <div class="see-more">
# <a href="/title/tt0111161/news?ref_=tt_nwr_sm">See all 2132 related articles</a> »
#             </div>
# </div>
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_RelatedNewsWidgetRHS_finished');
#     }
#   </script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "RelatedNewsWidgetRHS", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "RelatedNewsWidgetRHS", {wb: 1});
#     }
# </script>
# <!-- no content received for slot: middle_rhs -->
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "RelatedListsWidget", {wb: 1});
#     }
# </script>
# <div class="mini-article">
# <div id="relatedListsWidget">
# <div class="rightcornerlink">
# <a href="/list/create?ref_=tt_rls">Create a list</a> »
#                 </div>
# <h3>User Lists</h3>
# <p>Related lists from IMDb users</p>
# <div class="list-preview even">
# <div class="list-preview-item-narrow">
# <a href="/list/ls005582971?ref_=tt_rls_1"><img alt="list image" class="loadlate hidden " height="86" loadlate="http://ia.media-imdb.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_UX86_CR0,0,86,86_AL_.jpg" src="/images/nopicture/medium/film.png" title="list image" width="86"/></a> </div>
# <div class="list_name">
# <strong><a href="/list/ls005582971?ref_=tt_rls_1">Watched films</a></strong>
# </div>
# <div class="list_meta">
#             a list of 25 titles
#             <br/>created 17 Jul 2011
#         </div>
# <div class="clear"> </div>
# </div>
# <div class="list-preview odd">
# <div class="list-preview-item-narrow">
# <a href="/list/ls003891186?ref_=tt_rls_2"><img alt="list image" class="loadlate hidden " height="86" loadlate="http://ia.media-imdb.com/images/M/MV5BNTEyMjAwMDU1OV5BMl5BanBnXkFtZTcwNDQyNTkxMw@@._V1_UX86_CR0,0,86,86_AL_.jpg" src="/images/nopicture/medium/film.png" title="list image" width="86"/></a> </div>
# <div class="list_name">
# <strong><a href="/list/ls003891186?ref_=tt_rls_2">my favorites</a></strong>
# </div>
# <div class="list_meta">
#             a list of 25 titles
#             <br/>created 20 Nov 2011
#         </div>
# <div class="clear"> </div>
# </div>
# <div class="list-preview even">
# <div class="list-preview-item-narrow">
# ...
# </td>
# <td>
# <a href="/user/ur26360485/?ref_=tt_bd_5">maguew_9</a>
# </td>
# </tr>
# <tr class="even">
# <td>
# <a href="/title/tt0111161/board/nest/248967540?ref_=tt_bd_6">Shawshank and Forest Gump should have tied!!!</a>
# </td>
# <td>
# <a href="/user/ur5504407/?ref_=tt_bd_6">longlivepeewee</a>
# </td>
# </tr>
# </table>
# <div class="see-more">
# <a href="/title/tt0111161/board/?ref_=tt_bd_sm">Discuss The Shawshank Redemption (1994)</a> on the IMDb message boards »
#         </div>
# </div>
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_TitleMessageBoardsWidget_finished');
#     }
#   </script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "TitleMessageBoardsWidget", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "TitleMessageBoardsWidget", {wb: 1});
#     }
# </script>
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_TitleContributeWidget_started');
#     }
#   </script>
# <div class="article contribute">
# <div class="rightcornerlink">
# <a href="/help/?adding/&amp;ref_=tt_cn_hlp">Getting Started</a>
# <span>|</span>
# <a href="/czone/?ref_=tt_cn_cz">Contributor Zone</a> »</div>
# <h2>Contribute to This Page</h2>
# <div class="button-box">
# <form action="/updates?ref_=tt_cn_edt" method="post">
# <input name="auto" type="hidden" value="legacy/title/tt0111161/">
# <button class="btn primary large" rel="login" type="submit">Edit page</button>
# </input></form>
# </div>
# <div class="button-box">
# <a class="btn large" href="/title/tt0111161/reviews-enter?ref_=tt_cn_urv" rel="login">Write review</a>
# </div>
# <div class="form-box">
# <form accept-charset="ISO-8859-1" action="/character/create?ref_=tt_cn_ch" method="post">
# <input name="title" type="hidden" value="tt0111161">
# <div class="form-txt">Create a character page for:</div>
# <select data-tconst="tt0111161" id="character_select" name="name">
# <option value="1946 D.A.">1946 D.A.</option>
# <option value="Jigger">Jigger</option>
# <option value="Snooze">Snooze</option>
# <option value="Ernie">Ernie</option>
# <option value="Guard Mert">Guard Mert</option>
# <option disabled="disabled">-----------</option>
# <option value="...">more...</option>
# </select>
# <button class="btn small">Create »</button>
# <a class="btn small" href="/help/show_leaf?createchar&amp;ref_=tt_cn_chhlp">?</a>
# </input></form>
# </div>
# </div>
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_TitleContributeWidget_finished');
#     }
#   </script>
# </div>
# <br class="clear"/>
# </div>
# <br class="clear"/>
# </div>
# <div class="ft" id="footer">
# <div id="rvi-div">
# <div class="recently-viewed"> </div>
# <br class="clear">
# </br></div>
# <!-- no content received for slot: bottom_ad -->
# <div class="container footer-grid-wrapper">
# <div class="row footer-row">
# <div class="col outside">
# <h3>IMDb Everywhere</h3>
# <div class="app-links">
# <a href="/offsite/?page-action=ft_app_apple&amp;token=BCYvgj96yAPo8g-HpMZBYUJ8Z9zfHx6eoCsiTGsDD28Fo5klops-SgHZrmfrfAx5O0j5HM-zuzwR%0D%0A_VbJRyHbceLywfh7mknHKL-hre36MAKJk9cPZg5Uf2dTWn7uTkzstdMKlhrTyhCDhE-G9S_ET3zc%0D%0AiyS5dJSVx-oaVpHs2dgjQWkaTVhQIQSgUFJuGaU1wKXuMxnLZgF0Vci3qeRfi1Xp-XLTHy2OtZFk%0D%0AAOP165c9VMM%0D%0A&amp;ref_=ft_app_apple" itemprop="url" target="_blank" title="Get the IMDb App on the Apple App Store"> <span class="desktop-sprite appstore-apple"></span>
# </a>
# <a href="/offsite/?page-action=ft_app_google&amp;token=BCYjcqCvh3lr08nZoX201Yh-fNs2LRDVc1XgSe3y5MJIjT5pVjWfUNEj42ltg5ZVlMqCZwAfcdUD%0D%0Ao48MaZ1UVDmDAgkMm7jeHKN5DaLSjIlkfNFjYVMQGKyF-dFpR2W0Lvygi7U6Ja5vu9kPToAPAQ-U%0D%0AwF34KfSSWUHbU2dXoHFlp1iBRyzIvR6YIsYzQNMb231p39B6KIGLTGFW5Xuv5zjnCWXvdMHcSRCY%0D%0ACFZJA0xaaRQ%0D%0A&amp;ref_=ft_app_google" itemprop="url" target="_blank" title="Get the IMDb app on Google Play"> <span class="desktop-sprite appstore-google"></span>
# </a>
# <a href="/offsite/?page-action=ft_app_amazon&amp;token=BCYjmHy2twRICzmLZ883zsww0fxqoFJaMaE9MI_S8Ny2rGyyzwxkHC_dSOHZW-gleVHA3KbJrX-c%0D%0A-8PbPu-adlrD9EJdc0mO6HFyUI7qEpMm13wWrh2u2HeDFLthfbDzAu2ODQ3Th06QZo2juu2Odu-N%0D%0A3qgfXxbrbc1Hnx3BE4IrHKh9nyHXbUnPb3kZCgCWvjktnISCJLC5qb9hxet00sAWT9JOnK5Rvqtd%0D%0AB4cp72DRsMpUld97QBNJhiYhWkkszZ1eIg3VP6tgrXMRHeUvNXby17ErDvTBoDycTuLFdthWnHtM%0D%0A8gPQ4XsYamgCwhgHF9fbW1Z1TpuCqw0PNJ1Fo2f0MHu7RxGNI4IBzDtqIoyf-rG3lFMc6lnASjEE%0D%0AjGsR9FhOcaMUsOtLzC79judiGm_luj9h31d4fy_w1qTNUSVwWTo%0D%0A&amp;ref_=ft_app_amazon" itemprop="url" target="_blank" title="Get the IMDb app on Amazon Appstore for Android"> <span class="desktop-sprite appstore-amazon"></span>
# </a>
# </div>
# <p>Find showtimes, watch trailers, browse photos, track your Watchlist and rate your favorite movies and TV shows on your phone or tablet
0D%0A">
# <span class="amazon-affiliate-site-name">DPReview</span><br>
# <span class="amazon-affiliate-site-desc">Digital<br>Photography</br></span>
# </br></a>
# </div>
# </td>
# <td>
# <div>
# <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-aud&amp;token=BCYqGfxpaSlr2JVuukkqsYd54F2AjBrnYv72tUbcX5zdr-hnV9Krf8gT9sW7tO_FLdwukj9GVkDc%0D%0AsXT9QgqE7nmpUSOsiybT6heDcchTijK6lZ5RVTZ5_mrrU4V5lVDGL-VfGnC0JCRI35FKjJKkxv6c%0D%0AT0aDOuQ8cV86eUHR-U9Ob5w%0D%0A">
# <span class="amazon-affiliate-site-name">Audible</span><br>
# <span class="amazon-affiliate-site-desc">Download<br>Audio Books</br></span>
# </br></a>
# </div>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# <script src="http://ia.media-imdb.com/images/G/01/imdb/js/collections/common-2676354904._CB286425608_.js" type="text/javascript"></script>
# <script src="http://ia.media-imdb.com/images/G/01/imdb/js/collections/title-3910067851._CB285296548_.js" type="text/javascript"></script>
# <script id="login" type="text/javascript">
# (function(){
#     var readyTimeout = setInterval(function() {
#         if (window.jQuery && window.imdb && window.imdb.login_lightbox) {
#             clearTimeout(readyTimeout);
#             window.imdb.login_lightbox("https://secure.imdb.com", "http://www.imdb.com/title/tt0111161/");
#         }
#     }, 100);
# })();
# </script>
# <script type="text/javascript">
#         function jQueryOnReady(remaining_count) {
#             if (window.jQuery) {
#                 jQuery(
#                              function() {
#            var isAdvertisingThemed = !!(window.custom && window.custom.full_page && window.custom.full_page.theme),
#                url = "http://www.facebook.com/widgets/like.php?width=280&show_faces=1&layout=standard&href=http%3A%2F%2Fwww.imdb.com%2Ftitle%2Ftt0111161%2F&colorscheme=light",
#                like = document.getElementById('iframe_like');
#
#            if (!isAdvertisingThemed && like) {
#               like.src = url;
#               like.onload = function () { generic.monitoring.stop_timing('facebook_like_iframe', '', false); };
#            } else if (isAdvertisingThemed) {
#               $('.social_networking_like').closest('.aux-content-widget-2').hide();
#            }
#         }
#
#                 );
#                 jQuery(
#                              function() {
#             var facebookTheme = (window.custom && window.custom.full_page &&
#                     window.custom.full_page.theme) ?
#                 window.custom.full_page.theme : "light",
#             url = "//www.facebook.com/plugins/likebox.php?href=facebook.com%2Fimdb&width=300&height=190&connections=4&header=false&stream=false&colorscheme=" + facebookTheme,
#             like = document.getElementById('facebookIframe'),
#             twitterIframe = document.getElementById('twitterIframe');
#             if (like) {
#                 like.src = url;
#             }
#             if (twitterIframe) {
#                 twitterIframe.src = "http://i.media-imdb.com/images/social/twitter.html?10#imdb";
#             }
#          }
#
#                 );
#             } else if (remaining_count > 0) {
#                 setTimeout(function() { jQueryOnReady(remaining_count-1) }, 100);
#             }
#         }
#         jQueryOnReady(50);
#         </script>
# <div id="servertime" time="98"></div>
# <script>
#     if (typeof uet == 'function') {
#       uet("be");
#     }
# </script>
# </body>
# </html>

# %%
# run this code if you have encoding errors
import sys
reload(sys)
sys.setdefaultencoding('utf8')

# %% [markdown]
# #### Get the title

# %%
b.find('h1').text
# Out:
# u'The Shawshank Redemption\n                   (1994)\n                   \n'

# %% [markdown]
# #### Get the Star Rating (as a float)

# %%
# get the star rating (as a float)
float(b.find(name='span', attrs={'itemprop':'ratingValue'}).text)
# Out:
# 9.3

# %%
b.find_all(name='span', attrs={'class':'rating-rating'})
# Out:
# [<span class="rating-rating "><span class="value">9</span><span class="grey">/</span><span class="grey">10</span></span>,
#  <span class="rating-rating "><span class="value">9.2</span><span class="grey">/</span><span class="grey">10</span></span>,
#  <span class="rating-rating "><span class="value">8.8</span><span class="grey">/</span><span class="grey">10</span></span>,
#  <span class="rating-rating "><span class="value">8.9</span><span class="grey">/</span><span class="grey">10</span></span>,
#  <span class="rating-rating "><span class="value">8.9</span><span class="grey">/</span><span class="grey">10</span></span>,
#  <span class="rating-rating "><span class="value">8.8</span><span class="grey">/</span><span class="grey">10</span></span>,
#  <span class="rating-rating "><span class="value">9</span><span class="grey">/</span><span class="grey">10</span></span>,
#  <span class="rating-rating "><span class="value">8.9</span><span class="grey">/</span><span class="grey">10</span></span>,
#  <span class="rating-rating "><span class="value">8.6</span><span class="grey">/</span><span class="grey">10</span></span>,
#  <span class="rating-rating "><span class="value">8.8</span><span class="grey">/</span><span class="grey">10</span></span>,
#  <span class="rating-rating "><span class="value">8.5</span><span class="grey">/</span><span class="grey">10</span></span>,
#  <span class="rating-rating "><span class="value">8.7</span><span class="grey">/</span><span class="grey">10</span></span>]

# %% [markdown]
# #### Get the Movie Rating

# %%
panel = b.find('meta', attrs={'itemprop':'contentRating'}) # too many
panel.text
# Out:
# u'R\n| \n                        2h 22min\n                    \n|\nCrime, \nDrama\n|\n14 October 1994 (USA)\n\n '

# %% [markdown]
# ### Optional Wed Scraping Homework
#
# First, define a function that accepts an IMDb ID and returns a dictionary of
# movie information: title, star_rating, description, content_rating, duration.
# The function should gather this information by scraping the IMDb website, not
# by calling the OMDb API. (This is really just a wrapper of the web scraping
# code we wrote above.)
#
# For example, `get_movie_info('tt0111161')` should return:
# ```
# {'content_rating': 'R',
#  'description': u'Two imprisoned men bond over a number of years...',
#  'duration': 142,
#  'star_rating': 9.3,
#  'title': u'The Shawshank Redemption'}
#  ```
#
# Then, open the file imdb_ids.txt using Python, and write a for loop that builds
# a list in which each element is a dictionary of movie information.
# Finally, convert that list into a DataFrame.
#
# ### Bonus -- Challenge
#
# Can you scrape the IMDB Top 250 list (http://www.imdb.com/chart/top?ref_=nv_mv_250_6) and return a Data frame with the movide name, rating, year and the unique movie identifier ie('tt0111161')?
#
# Use the function above to scrape each of the movie pages.
#
# **Questions:**
#
# How many of the Top movies are rated 'R'?
#
# What is the average duration of movies with a star_rating above 9?
#
# What is the average duration of movies before 1985 and after?

# %%
import requests
def get_movie_info(uniq_id):
    r = requests.get('http://www.imdb.com/title/' + uniq_id + '/')
    b = BeautifulSoup(r.text, 'html.parser')
    title_year = b.find('h1').text.split('\n')
    title_name = title_year[0]
    year_name = title_year[1]
    descrip = b.find('div', {'class':'summary_text'}).text.split('\n')[1].strip()
    subtext = b.find('div', {'class': 'subtext'})
    rating = subtext.find('meta', {'itemprop':'contentRating'}).text.split('\n')[0]
    duration = subtext.find('time', {'itemprop':'duration'}).text.strip()
    ratingWrapper = b.find('div', {'class':'imdbRating'})
    star_rating = ratingWrapper.find('span', {'itemprop':'ratingValue'}).text
    return {'title':title_name, 'description':descrip, 
            'content_rating':rating, 'duration':duration,
           'star_rating':star_rating}

# %%
get_movie_info('tt0068646')
# Out:
# {'content_rating': u'R',
#  'description': u'The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.',
#  'duration': u'2h 55min',
#  'star_rating': u'9.2',
#  'title': u'The Godfather'}

# %%
import pandas as pd
with open('../../DAT-DC-10/data/imdb_ids.txt', 'r') as f:
    all_movie_info = [get_movie_info(mov_id.strip()) for mov_id in f]

# %%
pd.DataFrame(all_movie_info)
# Out:
#   content_rating                                        description  duration  \
# 0              R  Two imprisoned men bond over a number of years...  2h 22min
# 1          TV-MA  A Congressman works with his equally conniving...     51min
# 2          TV-PG  A TV show centered on six students and their y...     30min
# 3             PG  A young man is accidentally sent thirty years ...  1h 56min
# 4          PG-13  A thief who steals corporate secrets through u...  2h 28min
#
#   star_rating                     title
# 0         9.3  The Shawshank Redemption
# 1         9.0            House of Cards
# 2         7.0         Saved by the Bell
# 3         8.5        Back to the Future
# 4         8.8                 Inception

# %%
import requests
from bs4 import BeautifulSoup
r = requests.get('http://www.imdb.com/chart/top?ref_=nv_mv_250_6')
b = BeautifulSoup(r.text, 'html.parser')

# %%
movie_title_columns = b.find('div', {'class':'lister'}).find('tbody',{'class':'lister-list'}).find_all('td',{'class':'titleColumn'})
len(movie_title_columns)
# Out:
# 250

# %%
movie_links = [title_col.find('a')['href'].split('/')[2] for title_col in movie_title_columns]

# %%
imdb_250_info = [get_movie_info(mov_link.strip()) for mov_link in movie_links]

# %%
import pandas as pd
imdb_df = pd.DataFrame(imdb_250_info)

# %%
imdb_df
# Out:
#     content_rating                                        description  \
# 0                R  Two imprisoned men bond over a number of years...
# 1                R  The aging patriarch of an organized crime dyna...
# 2                R  The early life and career of Vito Corleone in ...
# 3            PG-13  When the menace known as the Joker wreaks havo...
# 4        Not Rated  A dissenting juror in a murder trial slowly ma...
# 5                R  In Poland during World War II, Oskar Schindler...
# 6                R  The lives of two mob hit men, a boxer, a gangs...
# 7        Not Rated  A bounty hunting scam joins two men in an unea...
# 8            PG-13  Gandalf and Aragorn lead the World of Men agai...
# 9                R  An insomniac office worker, looking for a way ...
# 10           PG-13  A meek Hobbit and eight companions set out on ...
# 11              PG  After the rebels have been brutally overpowere...
# 12           PG-13  Forrest Gump, while not intelligent, has accid...
# 13           PG-13  A thief who steals corporate secrets through u...
# 14               R  Upon admittance to a mental institution, a bra...
# 15           PG-13  While Frodo and Sam edge closer to Mordor with...
# 16               R  A computer hacker learns from mysterious rebel...
# 17               R  Henry Hill and his friends work their way up t...
# 18              PG  Luke Skywalker joins forces with a Jedi Knight...
# 19         Unrated  A poor village under attack by bandits recruit...
# 20               R  Two boys growing up in a violent neighborhood ...
# 21           PG-13  Three decades after the defeat of the Galactic...
# 22               R  Two detectives, a rookie and a veteran, hunt a...
# 23               R  A young F.B.I. cadet must confide in an incarc...
# 24               R  A sole survivor tells of the twisty events lea...
# 25        Approved  An angel helps a compassionate but despairingl...
# 26           PG-13  When an open-minded Jewish librarian and his s...
# 27               R  Mathilda, a 12-year-old girl, is reluctantly t...
# 28           PG-13  Epic story of a mysterious stranger with a har...
# 29           PG-13  A team of explorers travel through a wormhole ...
# ..             ...                                                ...
# 220              R  Two young Swedish children experience the many...
# 221        Unrated  A war-hardened general, egged on by his ambiti...
# 222      Not Rated  24 hours in the lives of three young men in th...
# 223          PG-13  A group of intergalactic criminals are forced ...
# 224              R  A semi-biographical account of Yip Man, the su...
# 225          PG-13  During World War II, mathematician Alan Turing...
# 226              R  The story of King George VI of the United King...
# 227             PG  A marshall, personally compelled to face a ret...
# 228              R  A wandering gunfighter plays two rival familie...
# 229              R  When Keller Dover's daughter and her friend go...
# 230          PG-13  Blacksmith Will Turner teams up with eccentric...
# 231             PG  A young boy and a girl with a magic crystal mu...
# 232          PG-13  An aspiring author during the civil rights mov...
# 233       Approved  A woman is asked to spy on a group of Nazi fri...
# 234      Not Rated  A bored and sheltered princess escapes her gua...
# 235          TV-MA  A bitter aging couple with the help of alcohol...
# 236              R  On an isolated lake, an old monk lives on a sm...
# 237              R  A man befriends a fellow criminal as the two o...
# 238              G  Belle, whose father is imprisoned by the Beast...
# 239       Approved  A religious fanatic marries a gullible widow w...
# 240        Unrated  In a murder trial, the defendant says he suffe...
# 241              R  Nine years after Jesse and Celine first met, t...
# 242             PG  The people of a small village in Victorian Ind...
# 243          PG-13  A true story about Frank Abagnale Jr., who, be...
# 244              R  Final entry in a trilogy of films dealing with...
# 245      Not Rated  A care-free girl is sold to a traveling entert...
# 246              R  A secret military project endangers Neo-Tokyo ...
# 247             PG  After killing a night-club owner, professional...
# 248       Approved  A disillusioned college graduate finds himself...
# 249             PG  Two neighbors, a woman and a man, form a stron...
#
#      duration star_rating                                              title
